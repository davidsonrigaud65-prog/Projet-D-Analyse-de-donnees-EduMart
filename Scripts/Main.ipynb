# %% [markdown]
# # MENU PRINCIPAL

# %% [markdown]
# ## Ce notebook exécute les 3 étapes d'analyse de manière interactive

# %% [markdown]
# ### Import des bibliothèques nécessaires

# %%
import pandas as pd
import numpy as np
import os
import sys
import warnings

# %% [markdown]
# ### Construction du menu

# %%
def afficher_menu():
    print("\n" + "="*60)
    print("        MENU PRINCIPAL - PROJET ANALYSE DES VENTES")
    print("="*60)
    print("1. Exécuter Étape 1 & 2 : Chargement, compréhension et nettoyage")
    print("2. Exécuter Étape 3 : ICP (Indicateurs Clés de Performance)")
    print("3. Exécuter Étape 4 : Jointures pour enrichir les ventes")
    print("4. Exécuter TOUT le projet (Étapes 1 → 2 → 3 → 4)")
    print("5. Afficher les livrables disponibles")
    print("0. Quitter")
    print("="*60)

# %% [markdown]
# ### Éxécution des étapes

# %%
def executer_etape_1_2():
    print("\n Étape 1 & 2 - Chargement, compréhension et nettoyage")
    # %run "Chargement, Comprehension et nettoyage des donnees.ipynb"
    print("Étape 1 & 2 terminées")


def executer_etape_3():
    print("\n Étape 3 - ICP (Indicateurs Clés de Performance)")
    # %run "ICP (Indicateur Clé de Performance).ipynb"
    print("Étape 3 terminée")


def executer_etape_4():
    print("\n Étape 4 - Jointures et enrichissement")
    # %run "Jointures (Merge) pour enrichir les ventes.ipynb"
    print("Étape 4 terminée")

# %% [markdown]
# ### Éxécution complète

# %%
def executer_tout():
    print("\n Exécution complète du projet")
    executer_etape_1_2()
    executer_etape_3()
    executer_etape_4()
    print("\n Projet exécuté avec succès")

# %% [markdown]
# ### Livrables

# %%
def afficher_livrables(dossier_racine=""C:\\Users\\DELL\\Desktop\\Formation Data-science_FRST_FDS\\Phase 1\\Introduction_Python\\Mini_Projet_Pandas"):
    print("\n LIVRABLES DISPONIBLES")

    if not os.path.exists(dossier_racine):
        print(f" Le dossier '{dossier_racine}' n'existe pas.")
        return

    livrables_trouves = False

    for racine, dossiers, fichiers in os.walk(dossier_racine):
        if fichiers:
            print(f"\n Dossier : {racine}")
            for fichier in fichiers:
                print(f"   - {fichier}")
                livrables_trouves = True


    if not livrables_trouves:
        print(" Aucun livrable trouvé.")

# %% [markdown]
# ### Boucle pricipale du menu

# %%
while True:
    afficher_menu()
    choix = input("Votre choix : ")

    if choix == "1":
        executer_etape_1_2()

    elif choix == "2":
        executer_etape_3()

    elif choix == "3":
        executer_etape_4()

    elif choix == "4":
        executer_tout()

    elif choix == "5":
        afficher_livrables()

    elif choix == "6":
        afficher_aide()

    elif choix == "0":
        print("\n Fin du programme. Merci !")
        break

    else:
        print(" Choix invalide. Veuillez réessayer.")
# Out:
# ...
#         MENU PRINCIPAL - PROJET ANALYSE DES VENTES
# ...
# 1. Exécuter Étape 1 & 2 : Chargement, compréhension et nettoyage
# 2. Exécuter Étape 3 : ICP (Indicateurs Clés de Performance)
# 3. Exécuter Étape 4 : Jointures pour enrichir les ventes
# 4. Exécuter TOUT le projet (Étapes 1 → 2 → 3 → 4)
# 5. Afficher les livrables disponibles
# 0. Quitter
# ...
# Votre choix :  1
#  Étape 1 & 2 - Chargement, compréhension et nettoyage
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  500 non-null    object
#  1   age          500 non-null    object
#  2   gender       490 non-null    object
#  3   city         485 non-null    object
#  4   segment      500 non-null    object
#  5   signup_date  500 non-null    object
# dtypes: object(6)
# memory usage: 23.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# ...
